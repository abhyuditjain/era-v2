# %%
from model import Session5Model
from utils import fit_model, get_dataloaders, visualize_data, model_summary, plot_data

# %%
train_loader, test_loader = get_dataloaders()
# Out:
# ...
# 100%|██████████| 9912422/9912422 [00:00<00:00, 11123698.02it/s]
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# ...
# 100%|██████████| 28881/28881 [00:00<00:00, 47244810.38it/s]
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
#
# ...
# 100%|██████████| 1648877/1648877 [00:00<00:00, 4002263.55it/s]
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
#
# ...
# 100%|██████████| 4542/4542 [00:00<00:00, 21453298.16it/s]
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw

# %%
visualize_data(train_loader, num_figures=12, label="Train Set")

# %%
visualize_data(test_loader, num_figures=12, label="Test Set")

# %%
model = Session5Model()
model_summary(model, input_size=(1, 1, 28, 28))
# Out:
# ...
# Layer (type (var_name))                  Kernel Shape              Input Shape               Output Shape              Param #
# ...
# Session5Model (Session5Model)            --                        [1, 1, 28, 28]            [1, 10]                   --
# ├─Conv2d (conv1)                         [3, 3]                    [1, 1, 28, 28]            [1, 32, 26, 26]           288
# ├─Conv2d (conv2)                         [3, 3]                    [1, 32, 26, 26]           [1, 64, 24, 24]           18,432
# ├─Conv2d (conv3)                         [3, 3]                    [1, 64, 12, 12]           [1, 128, 10, 10]          73,728
# ├─Conv2d (conv4)                         [3, 3]                    [1, 128, 10, 10]          [1, 256, 8, 8]            294,912
# ├─Linear (fc1)                           --                        [1, 4096]                 [1, 50]                   204,800
# ...

# %%
model = Session5Model()
results = fit_model(model, train_loader, test_loader, 20)
# Out:
# Epoch 1
#   0%|          | 0/118 [00:00<?, ?it/s]
# Train set: LR = 0.01 | Loss = 0.56 | Batch = 117 | Accuracy = 43.63 |: 100%|██████████| 118/118 [00:09<00:00, 12.80it/s]
# Test set: Average loss = 0.0006 | Accuracy = 9097/10000 (90.97%)
#
# Epoch 2
# Train set: LR = 0.01 | Loss = 0.11 | Batch = 117 | Accuracy = 92.92 |: 100%|██████████| 118/118 [00:10<00:00, 11.75it/s]
# Test set: Average loss = 0.0002 | Accuracy = 9614/10000 (96.14%)
#
# Epoch 3
# Train set: LR = 0.01 | Loss = 0.10 | Batch = 117 | Accuracy = 95.77 |: 100%|██████████| 118/118 [00:10<00:00, 11.36it/s]
# Test set: Average loss = 0.0001 | Accuracy = 9801/10000 (98.01%)
#
# Epoch 4
# Train set: LR = 0.01 | Loss = 0.06 | Batch = 117 | Accuracy = 96.81 |: 100%|██████████| 118/118 [00:09<00:00, 11.87it/s]
# Test set: Average loss = 0.0001 | Accuracy = 9832/10000 (98.32%)
#
# Epoch 5
# Train set: LR = 0.01 | Loss = 0.13 | Batch = 117 | Accuracy = 97.32 |: 100%|██████████| 118/118 [00:09<00:00, 12.00it/s]
# ...

# %%
plot_data(
    [
        results["train_losses"],
        results["train_accuracies"],
        results["test_losses"],
        results["test_accuracies"],
    ],
    [
        "Train Losses",
        "Train Accuracies",
        "Test Losses",
        "Test Accuracies",
    ],
)
